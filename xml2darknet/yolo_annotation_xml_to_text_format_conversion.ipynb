# %% [markdown]
# **XML to Text Conversion**
#
# While working with YOLO for object detection and classification using [DarkNet](https://github.com/pjreddie/darknet) with TensorFlow, in one method it requires annotation of images in textual format. While I am working with Face Mask Detection during this Covid19 pandemic using YOLOv5 alongwith DarkNet, I got the face mask image dataset with labelling of xml annotations. The xml annotation files are sometimes noisy. (0 image size..)
#
# The original version before modification is from: https://github.com/Isabek/XmlToTxt.git.

# %% [markdown]
# #Connect the drive to access and store data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# Install the requirements of XmlToTxt convertor
# !pip install declxml==0.9.1

# %%
# Clean the Input & Output directories
# !rm -rf xml/*.*

# %%
# Copy the XML files to be converted to text mode
# !cp '/content/drive/MyDrive/FMLD_annotations/FMLD_annotations/train'*.xml xml/

# %%
# All the XML files listed below
# !ls xml/
# Out:
# A streamkimeneten csak az utolsó 5000 sor látható.
#  train_00010833.xml
#  train_00010834.xml
#  train_00010835.xml
#  train_00010836.xml
#  train_00010837.xml
#  train_00010838.xml
#  train_00010839.xml
#  train_00010840.xml
#  train_00010841.xml
#  train_00010842.xml
#  train_00010843.xml
#  train_00010844.xml
#  train_00010845.xml
#  train_00010846.xml
#  train_00010847.xml
#  train_00010848.xml
#  train_00010849.xml
#  train_00010850.xml
#  train_00010851.xml
#  train_00010852.xml
#  train_00010853.xml
#  train_00010854.xml
#  train_00010855.xml
#  train_00010856.xml
#  train_00010857.xml
#  train_00010858.xml
#  train_00010859.xml
#  train_00010860.xml
#  train_00010861.xml
#  train_00010862.xml
#  train_00010863.xml
#  train_00010864.xml
#  train_00010865.xml
#  train_00010866.xml
#  train_00010867.xml
#  train_00010868.xml
#  train_00010869.xml
#  train_00010870.xml
#  train_00010871.xml
#  train_00010872.xml
#  train_00010873.xml
#  train_00010874.xml
#  train_00010875.xml
# ...

# %% [markdown]
# **Classes**
#
# This is most urgent part of this conversion. Don't forget to modify the classes.txt files as per the requirement of your classes mentioned in your input xml files. Classes tags in the XML files and classes.txt files must be the same else it may create problems.

# %%
# Modify the classes.txt files, create the classes.txt if it does not exist, list the classes in each row in the right order
# !cat classes.txt
# Out:
# incorrectly_masked_face
# masked_face
# unmasked_face

# %% [markdown]
# **Execution**
#
# Here we trigger the xmltotxt.py file to convert all the XML files to Text format of YOLO.

# %%
# !python xmltotxt.py -xml 'xml/' -out '/content/drive/MyDrive/FMLD'

# %%
# One of the sample input XMl file
# !cat /xml/train_00000035.xml
# Out:
# <annotation>
# 	<folder>train</folder>
# 	<filename>train_00000035.jpg</filename>
# 	<path>train-images/train_00000035.jpg</path>
# 	<source>
# 		<database>MAFA</database>
# 	</source>
# 	<size>
# 		<width>305</width>
# 		<height>458</height>
# 		<depth>3</depth>
# 	</size>
# 	<segmented>0</segmented>
# 	<object>
# 		<name>masked_face</name>
# 		<gender>unspecified</gender>
# 		<ethnicity>unspecified</ethnicity>
# 		<pose>unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>120.0</xmin>
# 			<ymin>68.0</ymin>
# 			<xmax>171.0</xmax>
# 			<ymax>119.0</ymax>
# 		</bndbox>
# 	</object>
# </annotation>

# %%
# Output text files of the same XML file above.
# !cat /content/drive/MyDrive/darknet/train_00006450.txt
# Out:
# 1 0.477586 0.255613 0.220690 0.221071
